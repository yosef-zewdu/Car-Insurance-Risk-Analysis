# %% [markdown]
# # Hypothesis Testing

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency, ttest_ind, f_oneway
import scipy.stats as  stats
import os
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('../data/cleaned_df.csv')
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID TransactionMonth  IsVATRegistered  \
# 0               145249     12827       2015-03-01             True
# 1               145249     12827       2015-05-01             True
# 2               145249     12827       2015-07-01             True
# 3               145255     12827       2015-05-01             True
# 4               145255     12827       2015-07-01             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  MaritalStatus Gender       Country Province  PostalCode  \
# 0  Current account  Not specified   Male  South Africa  Gauteng        1459
# 1  Current account  Not specified   Male  South Africa  Gauteng        1459
# 2  Current account  Not specified   Male  South Africa  Gauteng        1459
# 3  Current account  Not specified   Male  South Africa  Gauteng        1459
# 4  Current account  Not specified   Male  South Africa  Gauteng        1459
#
#   MainCrestaZone SubCrestaZone          ItemType      mmcode  \
# 0      Rand East     Rand East  Mobility - Motor  44069150.0
# 1      Rand East     Rand East  Mobility - Motor  44069150.0
# 2      Rand East     Rand East  Mobility - Motor  44069150.0
# 3      Rand East     Rand East  Mobility - Motor  44069150.0
# 4      Rand East     Rand East  Mobility - Motor  44069150.0
#
#          VehicleType  RegistrationYear           make  Model  Cylinders  \
# 0  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 1  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 2  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 3  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
# 4  Passenger Vehicle              2004  MERCEDES-BENZ  E 240        6.0
#
#    cubiccapacity  kilowatts bodytype  NumberOfDoors VehicleIntroDate  \
# 0         2597.0      130.0      S/D            4.0       2002-06-01
# 1         2597.0      130.0      S/D            4.0       2002-06-01
# 2         2597.0      130.0      S/D            4.0       2002-06-01
# 3         2597.0      130.0      S/D            4.0       2002-06-01
# 4         2597.0      130.0      S/D            4.0       2002-06-01
#
#    CustomValueEstimate AlarmImmobiliser TrackingDevice  CapitalOutstanding  \
# 0        225531.129942              Yes             No                 0.0
# 1        225531.129942              Yes             No                 0.0
# 2        225531.129942              Yes             No                 0.0
# 3        225531.129942              Yes             No                 0.0
# 4        225531.129942              Yes             No                 0.0
#
#            NewVehicle WrittenOff Rebuilt Converted  SumInsured TermFrequency  \
# 0  More than 6 months         No      No        No        0.01       Monthly
# 1  More than 6 months         No      No        No        0.01       Monthly
# 2  More than 6 months         No      No        No        0.01       Monthly
# 3  More than 6 months         No      No        No   119300.00       Monthly
# 4  More than 6 months         No      No        No   119300.00       Monthly
#
#    CalculatedPremiumPerTerm                    ExcessSelected CoverCategory  \
# 0                  25.00000             Mobility - Windscreen    Windscreen
# 1                  25.00000             Mobility - Windscreen    Windscreen
# 2                  25.00000             Mobility - Windscreen    Windscreen
# 3                 220.16145  Mobility - Metered Taxis - R2000    Own damage
# 4                 220.16145  Mobility - Metered Taxis - R2000    Own damage
#
#     CoverType            CoverGroup              Section  \
# 0  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 1  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 2  Windscreen  Comprehensive - Taxi  Motor Comprehensive
# 3  Own Damage  Comprehensive - Taxi  Motor Comprehensive
# 4  Own Damage  Comprehensive - Taxi  Motor Comprehensive
#
#                            Product StatutoryClass StatutoryRiskType  \
# 0  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 1  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 2  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 3  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
# 4  Mobility Metered Taxis: Monthly     Commercial     IFRS Constant
#
#    TotalPremium  TotalClaims
# 0     21.929825          0.0
# 1     21.929825          0.0
# 2      0.000000          0.0
# 3     54.824561          0.0
# 4      0.000000          0.0

# %%
df.describe()
# Out:
#        UnderwrittenCoverID       PolicyID     PostalCode        mmcode  \
# count        999470.000000  999470.000000  999470.000000  9.994700e+05
# mean         104803.753248    7955.776294    3019.521892  5.487731e+07
# std           63299.029829    5290.116355    2649.211826  1.360425e+07
# min               1.000000      14.000000       1.000000  4.041200e+06
# 25%           55127.000000    4500.000000     821.000000  6.005692e+07
# 50%           94069.000000    7070.000000    2000.000000  6.005842e+07
# 75%          139191.000000   11077.000000    4171.000000  6.005842e+07
# max          301175.000000   23246.000000    9870.000000  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count     999470.000000  999470.000000  999470.000000  999470.000000
# mean        2010.225291       4.046646    2472.572506      97.126102
# std            3.261126       0.294031     329.029918      18.872223
# min         1987.000000       0.000000    1551.500000      21.000000
# 25%         2008.000000       4.000000    2237.000000      75.000000
# 50%         2011.000000       4.000000    2694.000000     111.000000
# 75%         2013.000000       4.000000    2694.000000     111.000000
# max         2015.000000      10.000000    3379.500000     165.000000
#
#        NumberOfDoors  CustomValueEstimate  CapitalOutstanding     SumInsured  \
# count  999470.000000         9.994700e+05            999470.0  999470.000000
# mean        4.019251         2.255311e+05                 0.0  147613.189298
# std         0.468332         4.656615e-10                 0.0  225024.494297
# min         0.000000         2.255311e+05                 0.0       0.010000
# 25%         4.000000         2.255311e+05                 0.0    5000.000000
# 50%         4.000000         2.255311e+05                 0.0    7500.000000
# 75%         4.000000         2.255311e+05                 0.0  250000.000000
# max         6.000000         2.255311e+05                 0.0  617500.000000
#
#        CalculatedPremiumPerTerm   TotalPremium  TotalClaims
# count             999470.000000  999470.000000     999470.0
# mean                  63.237285      14.867722          0.0
# std                   83.104299      21.970816          0.0
# min                    0.000000     -32.894737          0.0
# 25%                    3.225700       0.000000          0.0
# 50%                    8.436900       2.179737          0.0
# 75%                   90.000000      21.929825          0.0
# max                  220.161450      54.824561          0.0

# %%
df.dtypes
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# bodytype                     object
# NumberOfDoors               float64
# VehicleIntroDate             object
# CustomValueEstimate         float64
# AlarmImmobiliser             object
# TrackingDevice               object
# CapitalOutstanding          float64
# NewVehicle                   object
# WrittenOff                   object
# Rebuilt                      object
# Converted                    object
# SumInsured                  float64
# TermFrequency                object
# CalculatedPremiumPerTerm    float64
# ExcessSelected               object
# CoverCategory                object
# CoverType                    object
# CoverGroup                   object
# Section                      object
# Product                      object
# StatutoryClass               object
# StatutoryRiskType            object
# TotalPremium                float64
# TotalClaims                 float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# UnderwrittenCoverID         0
# PolicyID                    0
# TransactionMonth            0
# IsVATRegistered             0
# Citizenship                 0
# LegalType                   0
# Title                       0
# Language                    0
# Bank                        0
# AccountType                 0
# MaritalStatus               0
# Gender                      0
# Country                     0
# Province                    0
# PostalCode                  0
# MainCrestaZone              0
# SubCrestaZone               0
# ItemType                    0
# mmcode                      0
# VehicleType                 0
# RegistrationYear            0
# make                        0
# Model                       0
# Cylinders                   0
# cubiccapacity               0
# kilowatts                   0
# bodytype                    0
# NumberOfDoors               0
# VehicleIntroDate            0
# CustomValueEstimate         0
# AlarmImmobiliser            0
# TrackingDevice              0
# CapitalOutstanding          0
# NewVehicle                  0
# WrittenOff                  0
# Rebuilt                     0
# Converted                   0
# SumInsured                  0
# TermFrequency               0
# CalculatedPremiumPerTerm    0
# ExcessSelected              0
# CoverCategory               0
# CoverType                   0
# CoverGroup                  0
# Section                     0
# Product                     0
# StatutoryClass              0
# StatutoryRiskType           0
# TotalPremium                0
# TotalClaims                 0
# dtype: int64

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# - Risk differences across provinces.
#
# Null Hypothesis: There are no risk differences across provinces

# %% [markdown]
# - Anova Test

# %%
# ANOVA test for provinces
province_groups = [group['TotalPremium'] for name, group in df.groupby('Province', observed=True )]
f_stat, p_value = f_oneway(*province_groups)
print(" F-statistic: ", f_stat, "\n p-value: ", p_value)
# Out:
#  F-statistic = 307.79269826029395
#  p-value = 0.0

# %% [markdown]
# - chi-square test

# %%
contingency_table = pd.crosstab(df['Province'], df['TotalPremium'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)
p_value
print(f'p-value: {p_value}')
print(f'chi-square value: {chi2}')
# Out:
# p-value: 0.0
# chi-square value: 1674886.2781617425

# %% [markdown]
# - Risk differences across postal code .
#
# Null Hypothesis: There are no risk differences across Postal code

# %% [markdown]
# - Anova test

# %%
# ANOVA test for provinces
postal_groups = [group['TotalPremium'] for name, group in df.groupby('PostalCode', observed=True )]
f_stat, p_value = stats.f_oneway(*postal_groups)
print("ANOVA for PostalCode: F-statistic =", f_stat, ", p-value =", p_value)
# Out:
# ANOVA for PostalCode: F-statistic = 45.938000494932616 , p-value = 0.0

# %% [markdown]
# - Null Hypothesis:
#
#  There are no significant margin (profit) difference between postal codes

# %%
# Create a new column for profit margin
dff = df.copy()
dff['ProfitMargin'] = dff['TotalPremium'] - dff['TotalClaims']

# ANOVA test for profit margins by zip code
profit_margin_groups = [group['ProfitMargin'] for name, group in dff.groupby('PostalCode', observed=True )]
f_stat_margin, p_value_margin = stats.f_oneway(*profit_margin_groups)
print("ANOVA for Profit Margins: F-statistic =", f_stat_margin, ", p-value =", p_value_margin)
# Out:
# ANOVA for Profit Margins: F-statistic = 45.938000494932616 , p-value = 0.0

# %% [markdown]
# - Null Hypothesis
#
# There are not significant risk difference between Women and Men

# %%
df_gender = df[df['Gender'].isin(['Male', 'Female'])]
# T-test for risk differences between genders
male_claims = df_gender[df_gender['Gender'] == 'Male']['TotalPremium']
female_claims = df_gender[df_gender['Gender'] == 'Female']['TotalPremium']
t_stat_gender, p_value_gender = stats.ttest_ind(male_claims, female_claims, equal_var=False)
print("T-Test for Gender Differences: t-statistic =", t_stat_gender, ", p-value =", p_value_gender)
# Out:
# T-Test for Gender Differences: t-statistic = 7.852301680470907 , p-value = 4.137958171186212e-15
